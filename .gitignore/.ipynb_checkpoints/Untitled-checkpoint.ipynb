# %%
from team_profle2 import *

df = pd.read_csv('TeamStatistics.csv')

def main():
  
    print(" Fiche descriptive d’une équipe NBA")
    teams = sorted(df["teamName"].unique())
    print("\n Équipes disponibles :")
    for team in teams:
        print(f"• {team}")
    
    team = input("Nom de l’équipe (ex: Nuggets) : ").strip()
    season = input("Saison (ex: 2024 pour la saison 2024–25) : ").strip()

    df_team, df_player = load_data("TeamStatistics.csv", "PlayerStatistics.csv")

    
    df_team_season, df_player_season = filter_team_season(df_team, df_player, team, season)

    if df_team_season.empty:
        print("\n Aucune donnée trouvée pour cette équipe et cette saison.")
        return

    show_team_summary(df_team_season, team)
    show_team_players(df_player_season)
    plot_wins_by_month(df_team_season, team)
    plot_team_score_progression(df_team_season, team)

if __name__ == "__main__":
    main()
# Out:
#  Fiche descriptive d’une équipe NBA
#
#  Équipes disponibles :
# • 76ers
# • Blackhawks
# • Bobcats
# • Braves
# • Bucks
# • Bullets
# • Bulls
# • Cavaliers
# • Celtics
# • Clippers
# • Grizzlies
# • Hawks
# • Heat
# • Hornets
# • Jazz
# • Kings
# • Knicks
# • Lakers
# • Magic
# • Mavericks
# • Nationals
# • Nets
# • Nuggets
# • Pacers
# • Packers
# • Pelicans
# • Pistons
# • Raptors
# • Rockets
# • Royals
# • Spurs
# • Suns
# • SuperSonics
# • Thunder
# • Timberwolves
# • Trail Blazers
# • Warriors
# • Wizards
# • Zephyrs
# Nom de l’équipe (ex: Nuggets) :  Lakers
# Saison (ex: 2024 pour la saison 2024–25) :  2021
#  Résumé de l’équipe : Lakers
# • Matchs joués : 88
# • Victoires : 33
#
#  Statistiques moyennes disponibles :
# teamScore              111.51
# assists                 23.88
# reboundsTotal           44.19
# turnovers               14.89
# foulsPersonal           20.39
# pointsFastBreak           NaN
# pointsFromTurnovers       NaN
# dtype: float64
#
#  Tous les joueurs de l’équipe par moyenne de points :
#
#            fullName    points
#        LeBron James 28.250000
#       Anthony Davis 21.068182
#   Russell Westbrook 18.240506
#          Malik Monk 13.610390
#     Carmelo Anthony 13.128571
# Talen Horton-Tucker  9.184615
#       Isaiah Thomas  7.400000
#     Stanley Johnson  6.666667
#      Wenyen Gabriel  6.047619
#         Mac McClung  6.000000
#       Austin Reaves  5.920000
#         DJ Augustin  5.333333
#       Avery Bradley  5.324324
#       Dwight Howard  4.831169
#     Wayne Ellington  3.776316
#         Mason Jones  3.375000
#     Sekou Doumbouya  2.333333
#      DeAndre Jordan  2.200000
#        Trevor Ariza  2.086957
#       Kent Bazemore  1.736842
#         Rajon Rondo  1.666667
#     Darren Collison  1.333333
#      Jemerrio Jones  0.800000
#      Chaundee Brown  0.500000
#            Jay Huff  0.000000
#       Kendrick Nunn  0.000000
